# %%
import pandas as pd 
import numpy as np
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from process import *
from datetime import timedelta

# %%
df_filt = pd.read_csv('df_filt.csv')
df_test = pd.read_csv('df_test.csv')   

df_filt = features_tsfel(df_filt, w_size=100, w_overlap=0, t_time=timedelta(microseconds=10000), n_jobs=4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 df_filt = pd.read_csv('df_filt.csv')
#       2 df_test = pd.read_csv('df_test.csv')
# ----> 4 df_filt = features_tsfel(df_filt, w_size=100, w_overlap=0, t_time=timedelta(microseconds=10000), n_jobs=4)
#
# TypeError: features_tsfel() missing 1 required positional argument: 'df_dir'
