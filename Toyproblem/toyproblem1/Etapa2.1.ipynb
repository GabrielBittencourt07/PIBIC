# %%
import pandas as pd 
import numpy as np
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from process import *
from datetime import timedelta
from sklearn.metrics import confusion_matrix

# %%
df_filt = pd.read_csv('df_filt.csv')
df_test = pd.read_csv('df_test.csv')   
df_filt['Timestamp'] = pd.to_datetime(df_filt['Timestamp'])
df_test['Timestamp'] = pd.to_datetime(df_test['Timestamp'])

df_filt.columns
# Out:
# Index(['Timestamp', 'Back.Acc.X', 'Back.Acc.Y', 'Back.Acc.Z', 'Back.Gyr.X',
#        'Back.Gyr.Y', 'Back.Gyr.Z', 'Back.Mag.X', 'Back.Mag.Y', 'Back.Mag.Z',
#        'Chest.Acc.X', 'Chest.Acc.Y', 'Chest.Acc.Z', 'Chest.Gyr.X',
#        'Chest.Gyr.Y', 'Chest.Gyr.Z', 'Chest.Mag.X', 'Chest.Mag.Y',
#        'Chest.Mag.Z', 'Neck.Acc.X', 'Neck.Acc.Y', 'Neck.Acc.Z', 'Neck.Gyr.X',
#        'Neck.Gyr.Y', 'Neck.Gyr.Z', 'Neck.Mag.X', 'Neck.Mag.Y', 'Neck.Mag.Z',
#        'Type', 'Position', 'Breed', 'Subject'],
#       dtype='object')

# %%
features_filt = features_tsfel(df_filt, w_size=100, w_overlap=0, t_time=timedelta(microseconds=10000), n_jobs=6)
# Out:
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='37',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='6',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='137',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='31',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='9',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='35',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='38',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='43',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='2',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='18',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='7',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='29',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='12',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='4',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='6',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='4',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='15',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='2',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='18',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='8',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='6',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='11',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='41',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='26',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='83',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='47',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='35',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='43',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='9',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='1',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='2',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='13',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='4',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='28',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='2',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='29',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='16',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='70',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='26',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='10',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='10',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='23',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='8',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='2',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='9',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='18',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='59',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='62',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='40',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='7',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='21',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='22',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='16',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='57',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='41',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='6',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='14',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='34',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='8',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='37',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='10',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='74',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='2',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='33',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='44',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='51',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='21',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='30',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='60',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='67',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='98',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='82',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='2',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='6',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='6',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='7',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='8',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='4',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='1',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='10',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='1',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='41',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='6',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='10',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='17',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='7',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='39',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='20',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='15',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='23',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='24',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='2',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='1',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='4',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='18',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='24',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='21',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='12',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='7',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='20',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='22',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='11',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='9',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='10',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='2',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='8',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='2',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='23',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='2',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='2',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='2',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='50',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='4',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='50',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='28',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='8',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='32',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='7',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='8',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='39',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='22',
#                   style='width: 25%',
#               >
#                   0
#               </progress>

# %%
# Rename columns ending with '_Mean' by prepending 'mean_'
mapping = {col: 'mean_' + col[:-5] for col in features_filt.columns if col.endswith('_Mean')}
features_filt.rename(columns=mapping, inplace=True)

# Rename columns ending with 'Standard deviation' by prepending 'std_'
mapping_std = {col: 'std_' + col.replace('Standard deviation', '').rstrip(' _.') for col in features_filt.columns if col.endswith('Standard deviation')}
features_filt.rename(columns=mapping_std, inplace=True)
print(features_filt.columns)
# Out:
# Index(['mean_Back.Acc.X', 'std_Back.Acc.X', 'mean_Back.Acc.Y',
#        'std_Back.Acc.Y', 'mean_Back.Acc.Z', 'std_Back.Acc.Z',
#        'mean_Back.Gyr.X', 'std_Back.Gyr.X', 'mean_Back.Gyr.Y',
#        'std_Back.Gyr.Y', 'mean_Back.Gyr.Z', 'std_Back.Gyr.Z',
#        'mean_Back.Mag.X', 'std_Back.Mag.X', 'mean_Back.Mag.Y',
#        'std_Back.Mag.Y', 'mean_Back.Mag.Z', 'std_Back.Mag.Z',
#        'mean_Chest.Acc.X', 'std_Chest.Acc.X', 'mean_Chest.Acc.Y',
#        'std_Chest.Acc.Y', 'mean_Chest.Acc.Z', 'std_Chest.Acc.Z',
#        'mean_Chest.Gyr.X', 'std_Chest.Gyr.X', 'mean_Chest.Gyr.Y',
#        'std_Chest.Gyr.Y', 'mean_Chest.Gyr.Z', 'std_Chest.Gyr.Z',
#        'mean_Chest.Mag.X', 'std_Chest.Mag.X', 'mean_Chest.Mag.Y',
#        'std_Chest.Mag.Y', 'mean_Chest.Mag.Z', 'std_Chest.Mag.Z',
#        'mean_Neck.Acc.X', 'std_Neck.Acc.X', 'mean_Neck.Acc.Y',
#        'std_Neck.Acc.Y', 'mean_Neck.Acc.Z', 'std_Neck.Acc.Z',
#        'mean_Neck.Gyr.X', 'std_Neck.Gyr.X', 'mean_Neck.Gyr.Y',
#        'std_Neck.Gyr.Y', 'mean_Neck.Gyr.Z', 'std_Neck.Gyr.Z',
#        'mean_Neck.Mag.X', 'std_Neck.Mag.X', 'mean_Neck.Mag.Y',
#        'std_Neck.Mag.Y', 'mean_Neck.Mag.Z', 'std_Neck.Mag.Z', 'Subject',
#        'Position'],
#       dtype='object')

# %%
features_test = features_tsfel(df_test, w_size=100, w_overlap=0, t_time=timedelta(microseconds=10000), n_jobs=6)
# Out:
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='6',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='7',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='79',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='24',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='24',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\multiprocessing\pool.py:856, in IMapIterator.next(self, timeout)
#     855 try:
# --> 856     item = self._items.popleft()
#     857 except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 features_test = features_tsfel(df_test, w_size=100, w_overlap=0, t_time=timedelta(microseconds=10000), n_jobs=6)
#
# File c:\Users\julia\.vscode\PIBIC\Toyproblem\toyproblem1\process.py:91, in features_tsfel(df_raw, w_size, w_overlap, t_time, n_jobs)
#      87 for (s_idx, f_idx) in zip(s_indices, f_indices):
#      89     if(df.loc[s_idx:f_idx].shape[0] >= w_size):
# ---> 91         df_list.append(tsfel.time_series_features_extractor(
#      92                         # configuration file with features to be extracted
#      93                         config = cfg,
#      94                         # dataframe window to calculate features window on
#      95                         timeseries = df.loc[s_idx:f_idx, cols],
#      96                         # name of header columns
#      97                         header_names = cols,
#      98                         # sampling frequency of original signal
#      99                         fs = 100,
#     100                         # sliding window size
#     101                         window_size = w_size,
#     102                         # overlap between subsequent sliding windows
#     103                         overlap = w_overlap,
#     104                         # do not create a progress bar
#     105                         verbose = 0,
#     106                         # número de jobs para processamento paralelo
#     107                         n_jobs = n_jobs).assign(
#     108                         Timestamp = df.loc[s_idx, 'Timestamp'],
#     109                         Subject = df.loc[s_idx,'Subject'],
#     110                         Position = df.loc[s_idx, 'Position']))
#     113 df_feat = pd.concat(df_list)
#     114 df_feat.set_index('Timestamp', inplace = True)
#
# File c:\Users\julia\.vscode\PIBIC\.venv\Lib\site-packages\tsfel\feature_extraction\calc_features.py:348, in time_series_features_extractor(config, timeseries, fs, window_size, overlap, verbose, **kwargs)
#     335 pool = ctx.Pool(cpu_count)
#     337 features = pool.imap(
#     338     partial(
#     339         _calc_features,
#    (...)    345     timeseries,
#     346 )
# --> 348 for i, feat in enumerate(features):
#     349     if verbose == 1:
#     350         display_progress_bar(i, len(timeseries), out)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\multiprocessing\pool.py:861, in IMapIterator.next(self, timeout)
#     859     self._pool = None
#     860     raise StopIteration from None
# --> 861 self._cond.wait(timeout)
#     862 try:
#     863     item = self._items.popleft()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:

# %%
features_filt_50 = features_tsfel(df_filt, w_size=100, w_overlap=0.5, t_time=timedelta(microseconds=5000), n_jobs=6)
# Out:
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='73',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='11',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='273',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='61',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='17',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='69',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='75',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='85',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='35',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='13',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='57',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='23',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='7',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='11',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='7',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='29',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='35',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='15',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='11',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='21',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='81',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='51',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='165',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='93',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='69',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='85',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='17',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='1',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='25',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='7',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='55',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='57',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='31',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='139',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='51',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='19',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='19',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='45',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='9',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='15',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='17',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='35',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='117',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='123',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='79',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='13',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='41',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='43',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='31',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='113',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='81',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='11',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='27',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='67',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='9',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='15',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='73',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='19',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='147',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='65',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='87',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='101',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='41',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='59',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='119',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='133',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='195',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='163',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='9',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='11',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='11',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='13',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='15',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='7',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='1',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='19',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='1',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='81',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='11',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='19',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='33',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='13',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='77',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='39',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='29',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='9',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='45',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='47',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='9',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='9',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='1',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='7',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='35',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='47',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='41',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='23',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='13',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='39',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='43',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='21',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='17',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='19',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='15',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='45',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='99',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='7',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='99',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='55',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='15',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='63',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='13',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='15',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='77',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='44',
#                   style='width: 25%',
#               >
#                   0
#               </progress>

# %%
features_test_50 = features_tsfel(df_test, w_size=100, w_overlap=0.5, t_time=timedelta(microseconds=5000), n_jobs=6)
# Out:
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='11',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='13',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='157',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='47',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='47',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='9',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='89',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='71',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='101',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='17',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='77',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='11',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='11',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='49',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='23',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='67',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='9',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='9',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='29',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='61',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='107',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='39',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='15',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='9',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='1',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='25',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='15',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='137',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='23',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='11',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='7',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='79',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='97',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='81',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='7',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='15',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='65',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='15',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='11',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='1',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='13',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='45',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='9',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='15',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='29',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='11',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='11',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='59',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='27',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='13',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='21',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='11',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='9',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='7',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='29',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='145',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='1',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='9',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='97',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='41',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='7',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='47',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='13',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='15',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='29',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='165',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='61',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='101',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='93',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='77',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='99',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='33',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='17',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='41',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='13',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='75',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='11',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='23',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='21',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='9',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='11',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='9',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='7',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='53',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='61',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='159',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='21',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='89',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='39',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='233',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='75',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='72',
#                   style='width: 25%',
#               >
#                   0
#               </progress>

# %%
def get_axis(ax:str, dataframe:pd.DataFrame) -> pd.DataFrame: 
    """Filtra o Eixo de um dataframe"""
    dataframe_ax = pd.DataFrame()
    for col in dataframe.columns: 
        if col.endswith(ax):
            dataframe_ax[col] = dataframe[col] 
    return dataframe_ax

def get_axis_mean(ax: str, dataframe: pd.DataFrame) -> pd.DataFrame:
    """Retorna um Dataframe com com a média das médias e dos desvios padrões de um eixo específico"""
    dataframe_ax_mean = pd.DataFrame()
    dataframe_ax_std = pd.DataFrame()

    for col in dataframe: 
        if col.endswith(ax):
            if col.startswith("mean"):
                dataframe_ax_mean[col] = dataframe[col]
            else: 
                dataframe_ax_std[col] = dataframe[col]
    
    dataframe_ax_mean = dataframe_ax_mean.mean(axis = 1 )
    dataframe_ax_std = dataframe_ax_std.mean(axis = 1 )
        
    return pd.DataFrame({f"mean_media_{ax}": dataframe_ax_mean, f"mean_Desviopadrao_{ax}": dataframe_ax_std})

def get_axis_sum(ax: str, dataframe: pd.DataFrame) -> pd.DataFrame: 
    """Faz a soma do desvio padrão que acontece em um eixo em específico"""
    dataframe_ax_std = pd.DataFrame()

    for col in dataframe: 
        if col.endswith(ax):
            if col.startswith("std"):
                dataframe_ax_std[col] = dataframe[col]
            
    dataframe_ax_sum_std = dataframe_ax_std.sum(axis = 1 )

    return pd.DataFrame({f"soma_std_{ax}":dataframe_ax_sum_std})


def get_sensor(sensor: str, dataframe: pd.DataFrame) -> pd.DataFrame:
    dataframe_sensor = pd.DataFrame()
    for col in dataframe.columns: 
        if sensor in col: 
            dataframe_sensor[col] = dataframe[col]

    return dataframe_sensor

def df_num(df) -> pd.DataFrame:
    """Retorna um Dataframe apenas com as colunas numéricas"""
    df_numerico = df.select_dtypes(include=[np.number])
    return df_numerico

# %%
standing = features_filt[features_filt["Position"] == "standing"]
conjunto_sensores = pd.Series(features_filt.columns).str.extract(r'^(.*)\.(?:X|Y|Z)')[0].dropna().unique().tolist()
eixos = ("X", "Y", "Z")

dict_sensores = {}

for sensor in conjunto_sensores:
    df_sensor = get_sensor(sensor, standing)
    dict_valores = {}

    for ax in eixos:
        col_df = get_axis(ax, df_sensor)

        # caso 1: não existe esse eixo → col_df vazio
        if col_df is None or len(col_df.columns if isinstance(col_df, pd.DataFrame) else col_df) == 0:
            dict_valores[f"mean_{ax}"] = None
            continue

        # caso 2: veio DataFrame → pegar a primeira coluna
        if isinstance(col_df, pd.DataFrame):
            col_series = col_df.iloc[:, 0]
        else:
            col_series = col_df

        dict_valores[f"mean_{ax}"] = float(col_series.mean())

    dict_sensores[sensor] = dict_valores

print(dict_sensores)
# Out:
# {'mean_Back.Acc': {'mean_X': 0.0618956376699029, 'mean_Y': 0.01379852145631068, 'mean_Z': 0.9869498473786407}, 'std_Back.Acc': {'mean_X': 0.0979174310921173, 'mean_Y': 0.09820910333145062, 'mean_Z': 0.06663172395320706}, 'mean_Back.Gyr': {'mean_X': -1.1458363484466016, 'mean_Y': -0.2317967234951452, 'mean_Z': -3.4489153192233015}, 'std_Back.Gyr': {'mean_X': 16.298904410002837, 'mean_Y': 19.86350777658396, 'mean_Z': 16.936061881382404}, 'mean_Back.Mag': {'mean_X': 19.145834980873786, 'mean_Y': -5.6031028651456305, 'mean_Z': 20.804228862427188}, 'std_Back.Mag': {'mean_X': 1.8688814338028301, 'mean_Y': 1.6277162269854113, 'mean_Z': 1.1976529140977075}, 'mean_Chest.Acc': {'mean_X': -0.2963278394174757, 'mean_Y': 0.06960418611650485, 'mean_Z': -0.9401505459223302}, 'std_Chest.Acc': {'mean_X': 0.10594172786426836, 'mean_Y': 0.12642492604125669, 'mean_Z': 0.09824890567319727}, 'mean_Chest.Gyr': {'mean_X': 1.675557064466019, 'mean_Y': 0.2508280814563108, 'mean_Z': 1.778455706019417}, 'std_Chest.Gyr': {'mean_X': 22.763464195202612, 'mean_Y': 26.626017459778517, 'mean_Z': 19.91018121480822}, 'mean_Chest.Mag': {'mean_X': 21.716404110485435, 'mean_Y': 46.072862845048554, 'mean_Z': -64.01012338961164}, 'std_Chest.Mag': {'mean_X': 1.933127457566656, 'mean_Y': 1.6306097813780756, 'mean_Z': 1.5035999117277916}, 'mean_Neck.Acc': {'mean_X': -0.38094177718446587, 'mean_Y': -0.3988508287378641, 'mean_Z': -0.7318606650485436}, 'std_Neck.Acc': {'mean_X': 0.12147908863847559, 'mean_Y': 0.11093546737663998, 'mean_Z': 0.14990250186878737}, 'mean_Neck.Gyr': {'mean_X': -3.453894607669902, 'mean_Y': -0.7036421240776697, 'mean_Z': 1.119809232912621}, 'std_Neck.Gyr': {'mean_X': 33.99330601022387, 'mean_Y': 32.41695985487516, 'mean_Z': 29.388293355596144}, 'mean_Neck.Mag': {'mean_X': 32.71343329601942, 'mean_Y': 54.35796491368932, 'mean_Z': -32.04834392776699}, 'std_Neck.Mag': {'mean_X': 3.119402178896858, 'mean_Y': 2.230276412446566, 'mean_Z': 2.897068913392927}}

# %%
# For each sensor compute Euclidean distance from its mean (using mean_ columns)
for sensor in conjunto_sensores:
    # get all columns for this sensor and keep only mean_ columns
    df_sensor = get_sensor(sensor, features_filt)
    # keep columns that start with 'mean_' and contain the sensor name
    if df_sensor.shape[1] > 0:
        df_sensor = df_sensor.loc[:, df_sensor.columns.str.startswith('mean_') & df_sensor.columns.str.contains(sensor)]

    dist_euc_sq = pd.Series(0.0, index=features_filt.index)
    for eixo in eixos:
        col_df = get_axis(eixo, df_sensor)
        if col_df is None or (isinstance(col_df, pd.DataFrame) and col_df.shape[1] == 0):
            continue
        if isinstance(col_df, pd.DataFrame):
            col_series = col_df.iloc[:, 0]
        else:
            col_series = col_df
        mean_ref = dict_sensores.get(sensor, {}).get(f"mean_{eixo}", 0.0)
        dist_euc_sq += (col_series - mean_ref) ** 2
    features_filt[f"dist_euc_{sensor}"] = np.sqrt(dist_euc_sq)

# Sum stds per axis (uses columns that start with 'std_' and end with axis)
for eixo in eixos:
    df_axis_sum = get_axis_sum(eixo, features_filt)
    features_filt[f"soma_std_{eixo}"] = df_axis_sum[f"soma_std_{eixo}"]

# Sum stds per sensor (columns that start with 'std_{sensor}')
for sensor in conjunto_sensores:
    s = pd.Series(0.0, index=features_filt.index)
    for col in features_filt.columns:
        if col.startswith(f"std_{sensor}"):
            s += features_filt[col]
    features_filt[f"sum_std_{sensor}"] = s

# keep Position from original dataframe if available
if 'Position' not in features_filt.columns and 'Position' in df_filt.columns:
    features_filt['Position'] = df_filt['Position']

print('Total columns:', len(features_filt.columns))
print([c for c in features_filt.columns if c.startswith(('mean_','std_','dist_euc_','sum_std_','soma_std_'))][:100])
# Out:
# n_cols_total = 95
# ['mean_Back.Acc.X', 'std_Back.Acc.X', 'mean_Back.Acc.Y', 'std_Back.Acc.Y', 'mean_Back.Acc.Z', 'std_Back.Acc.Z', 'mean_Back.Gyr.X', 'std_Back.Gyr.X', 'mean_Back.Gyr.Y', 'std_Back.Gyr.Y', 'mean_Back.Gyr.Z', 'std_Back.Gyr.Z', 'mean_Back.Mag.X', 'std_Back.Mag.X', 'mean_Back.Mag.Y', 'std_Back.Mag.Y', 'mean_Back.Mag.Z', 'std_Back.Mag.Z', 'mean_Chest.Acc.X', 'std_Chest.Acc.X', 'mean_Chest.Acc.Y', 'std_Chest.Acc.Y', 'mean_Chest.Acc.Z', 'std_Chest.Acc.Z', 'mean_Chest.Gyr.X', 'std_Chest.Gyr.X', 'mean_Chest.Gyr.Y', 'std_Chest.Gyr.Y', 'mean_Chest.Gyr.Z', 'std_Chest.Gyr.Z', 'mean_Chest.Mag.X', 'std_Chest.Mag.X', 'mean_Chest.Mag.Y', 'std_Chest.Mag.Y', 'mean_Chest.Mag.Z', 'std_Chest.Mag.Z', 'mean_Neck.Acc.X', 'std_Neck.Acc.X', 'mean_Neck.Acc.Y', 'std_Neck.Acc.Y', 'mean_Neck.Acc.Z', 'std_Neck.Acc.Z', 'mean_Neck.Gyr.X', 'std_Neck.Gyr.X', 'mean_Neck.Gyr.Y', 'std_Neck.Gyr.Y', 'mean_Neck.Gyr.Z', 'std_Neck.Gyr.Z', 'mean_Neck.Mag.X', 'std_Neck.Mag.X']

# %%
columns_mean_filt = df_filt.columns[df_filt.columns.str.contains(r'\.(X|Y|Z)_Mean$', regex=True)]
columns_mean_test = df_test.columns[df_test.columns.str.contains(r'\.(X|Y|Z)_Mean$', regex=True)]

dados_mean_filt = df_filt[columns_mean_filt]
dados_mean_test = df_test[columns_mean_test]

x_treino = dados_mean_filt
y_treino = df_filt["Position"]
x_teste = dados_mean_test
y_teste = df_test["Position"]

rf = RandomForestClassifier(
    n_estimators=300,        # número de árvores
    max_depth=12,          # deixe None inicialmente
    min_samples_split=2,
    min_samples_leaf=1,     # padrão bom para classificação
    bootstrap=True,
    n_jobs=6,
    random_state=42
)

rf.fit(x_treino, y_treino)
y_pred = rf.predict(x_teste)

acc = accuracy_score(y_teste, y_pred)
print(f"Acurácia: {acc:.4f}")

print(classification_report(y_teste, y_pred))

cm = confusion_matrix(y_teste, y_pred)
print(cm)
# Out:
# C:\Users\julia\AppData\Local\Temp\ipykernel_5992\1986011192.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   columns_mean_filt = df_filt.columns[df_filt.columns.str.contains(r'\.(X|Y|Z)_Mean$', regex=True)]
# C:\Users\julia\AppData\Local\Temp\ipykernel_5992\1986011192.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   columns_mean_test = df_test.columns[df_test.columns.str.contains(r'\.(X|Y|Z)_Mean$', regex=True)]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 22
#      10 y_teste = df_test["Position"]
#      12 rf = RandomForestClassifier(
#      13     n_estimators=300,        # número de árvores
#      14     max_depth=12,          # deixe None inicialmente
#    (...)     19     random_state=42
#      20 )
# ---> 22 rf.fit(x_treino, y_treino)
#      23 y_pred = rf.predict(x_teste)
#      25 acc = accuracy_score(y_teste, y_pred)
#
# File c:\Users\julia\.vscode\PIBIC\.venv\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\julia\.vscode\PIBIC\.venv\Lib\site-packages\sklearn\ensemble\_forest.py:359, in BaseForest.fit(self, X, y, sample_weight)
#     356 if issparse(y):
#     357     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 359 X, y = validate_data(
#     360     self,
#     361     X,
#     362     y,
#     363     multi_output=True,
#     364     accept_sparse="csc",
#     365     dtype=DTYPE,
#     366     ensure_all_finite=False,
#     367 )
#     368 # _compute_missing_values_in_feature_mask checks if X has missing values and
#     369 # will raise an error if the underlying tree base estimator can't handle missing
#     370 # values. Only the criterion is required to determine if the tree supports
#     371 # missing values.
#     372 estimator = type(self.estimator)(criterion=self.criterion)
#
# File c:\Users\julia\.vscode\PIBIC\.venv\Lib\site-packages\sklearn\utils\validation.py:2919, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2917         y = check_array(y, input_name="y", **check_y_params)
#    2918     else:
# -> 2919         X, y = check_X_y(X, y, **check_params)
#    2920     out = X, y
#    2922 if not no_val_X and check_params.get("ensure_2d", True):
#
# File c:\Users\julia\.vscode\PIBIC\.venv\Lib\site-packages\sklearn\utils\validation.py:1314, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1309         estimator_name = _check_estimator_name(estimator)
#    1310     raise ValueError(
#    1311         f"{estimator_name} requires y to be passed, but the target y is None"
#    1312     )
# -> 1314 X = check_array(
#    1315     X,
#    1316     accept_sparse=accept_sparse,
#    1317     accept_large_sparse=accept_large_sparse,
#    1318     dtype=dtype,
#    1319     order=order,
#    1320     copy=copy,
#    1321     force_writeable=force_writeable,
#    1322     ensure_all_finite=ensure_all_finite,
#    1323     ensure_2d=ensure_2d,
#    1324     allow_nd=allow_nd,
#    1325     ensure_min_samples=ensure_min_samples,
#    1326     ensure_min_features=ensure_min_features,
#    1327     estimator=estimator,
#    1328     input_name="X",
#    1329 )
#    1331 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1333 check_consistent_length(X, y)
#
# File c:\Users\julia\.vscode\PIBIC\.venv\Lib\site-packages\sklearn\utils\validation.py:898, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     894 pandas_requires_conversion = any(
#     895     _pandas_dtype_needs_early_conversion(i) for i in dtypes_orig
#     896 )
#     897 if all(isinstance(dtype_iter, np.dtype) for dtype_iter in dtypes_orig):
# --> 898     dtype_orig = np.result_type(*dtypes_orig)
#     899 elif pandas_requires_conversion and any(d == object for d in dtypes_orig):
#     900     # Force object if any of the dtypes is an object
#     901     dtype_orig = object
#
# ValueError: at least one array or dtype is required

# %%
columns_std_filt = df_filt.columns[df_filt.columns.str.contains(r'\.(X|Y|Z)_Standard deviation$', regex=True)]
columns_std_test = df_test.columns[df_test.columns.str.contains(r'\.(X|Y|Z)_Standard deviation$', regex=True)]
dados_std_filt = df_filt[columns_std_filt]
dados_std_test = df_test[columns_std_test]
x_treino_std = dados_std_filt
x_teste_std = dados_std_test
y_treino_std = df_filt["Position"]
y_teste_std = df_test["Position"]

rf = RandomForestClassifier(
    n_estimators=300,        # número de árvores
    max_depth=12,          # deixe None inicialmente
    min_samples_split=2,
    min_samples_leaf=1,     # padrão bom para classificação
    bootstrap=True,
    n_jobs=6,
    random_state=42
)

rf.fit(x_treino_std, y_treino_std)
y_pred_std = rf.predict(x_teste_std)

acc_std = accuracy_score(y_teste_std, y_pred_std)
print(f"Acurácia (std): {acc_std:.4f}")

print(classification_report(y_teste_std, y_pred_std))
cm_std = confusion_matrix(y_teste_std, y_pred_std)
print(cm_std)
# Out:
# C:\Users\assis\AppData\Local\Temp\ipykernel_8376\4091284723.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   columns_std_filt = df_filt.columns[df_filt.columns.str.contains(r'\.(X|Y|Z)_Standard deviation$', regex=True)]
# C:\Users\assis\AppData\Local\Temp\ipykernel_8376\4091284723.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   columns_std_test = df_test.columns[df_test.columns.str.contains(r'\.(X|Y|Z)_Standard deviation$', regex=True)]
# Acurácia (std): 0.8578
#               precision    recall  f1-score   support
#
#   body shake       0.00      0.00      0.00         4
#   lying down       0.00      0.00      0.00         0
#      sitting       0.84      0.92      0.88       220
#     standing       0.82      0.70      0.75       127
#      walking       0.97      0.99      0.98        78
#
#     accuracy                           0.86       429
#    macro avg       0.53      0.52      0.52       429
# weighted avg       0.85      0.86      0.85       429
#
# [[  0   0   0   2   2]
#  [  0   0   0   0   0]
#  [  0   1 202  17   0]
#  [  0   0  38  89   0]
#  [  0   0   0   1  77]]
# c:\Users\assis\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\assis\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\assis\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\assis\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\assis\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\assis\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
# # Definindo os hiperparâmetros para Grid Search (3 valores para cada)
# param_grid = {
#     'n_estimators': [100, 200, 300],           # número de árvores
#     'max_depth': [10, 15, 20],                # profundidade máxima
#     'min_samples_leaf': [10, 20, 30]         # mínimo de amostras por folha
# }

# # Criando o modelo base
# rf_base = RandomForestClassifier(
#     n_estimators=300,        # número de árvores
#     max_depth=12,          # deixe None inicialmente
#     min_samples_split=2,
#     min_samples_leaf=1,     # padrão bom para classificação
#     bootstrap=True,
#     n_jobs=6,
#     random_state=42
# )

# # Grid Search com Cross-Validation de 5 folds
# # print("Iniciando Grid Search com 5-fold Cross-Validation...")
# # print(f"Total de combinações: {len(param_grid['n_estimators']) * len(param_grid['max_depth']) * len(param_grid['min_samples_leaf'])}")
# # print("="*60)

# # grid_search = GridSearchCV(
# #     estimator=rf_base,
# #     param_grid=param_grid,
# #     cv=5,                    # 5 folds
# #     scoring='accuracy',
# #     n_jobs=6,
# #     verbose=2,
# #     return_train_score=True
# # )
