# %%
import pandas as pd 
import numpy as np
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from process import *
from datetime import timedelta
from sklearn.metrics import confusion_matrix

# %%
df_filt = pd.read_csv('df_filt.csv')
df_test = pd.read_csv('df_test.csv')   
df_filt['Timestamp'] = pd.to_datetime(df_filt['Timestamp'])
df_test['Timestamp'] = pd.to_datetime(df_test['Timestamp'])

# %%
features_filt = features_tsfel(df_filt, w_size=100, w_overlap=0, t_time=timedelta(microseconds=10000), n_jobs=6)
# Out:
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='37',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='6',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='137',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='31',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='9',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='35',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='38',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='43',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='2',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='18',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='7',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='29',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='12',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='4',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='6',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='4',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='15',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='2',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='18',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='8',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='6',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='11',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='41',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='26',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='83',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='47',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='35',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='43',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='9',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='1',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='2',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='13',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='4',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='28',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='2',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='29',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='16',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='70',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='26',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='10',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='10',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='23',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='8',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='2',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='9',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='18',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='59',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='62',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='40',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='7',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='21',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='22',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='16',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='57',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='41',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='6',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='14',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='34',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='8',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='37',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='10',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='74',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='2',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='33',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='44',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='51',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='21',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='30',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='60',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='67',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='98',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='82',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='2',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='6',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='6',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='7',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='8',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='4',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='1',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='10',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='1',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='41',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='6',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='10',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='17',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='7',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='39',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='20',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='15',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='23',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='24',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='2',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='1',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='4',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='18',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='24',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='21',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='12',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='7',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='20',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='22',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='11',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='9',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='10',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='2',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='8',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='2',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='23',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='2',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='2',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='2',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='50',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='4',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='50',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='28',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='8',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='32',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='7',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='8',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='39',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='22',
#                   style='width: 25%',
#               >
#                   0
#               </progress>

# %%
print(features_filt.columns)
# Out:
# Index(['Back.Acc.X_Absolute energy', 'Back.Acc.X_Area under the curve',
#        'Back.Acc.X_Autocorrelation', 'Back.Acc.X_Average power',
#        'Back.Acc.X_Centroid', 'Back.Acc.X_ECDF Percentile Count_0',
#        'Back.Acc.X_ECDF Percentile Count_1', 'Back.Acc.X_ECDF Percentile_0',
#        'Back.Acc.X_ECDF Percentile_1', 'Back.Acc.X_ECDF_0',
#        ...
#        'Neck.Mag.Z_Wavelet variance_25.0Hz',
#        'Neck.Mag.Z_Wavelet variance_3.12Hz',
#        'Neck.Mag.Z_Wavelet variance_3.57Hz',
#        'Neck.Mag.Z_Wavelet variance_4.17Hz',
#        'Neck.Mag.Z_Wavelet variance_5.0Hz',
#        'Neck.Mag.Z_Wavelet variance_6.25Hz',
#        'Neck.Mag.Z_Wavelet variance_8.33Hz', 'Neck.Mag.Z_Zero crossing rate',
#        'Subject', 'Position'],
#       dtype='object', length=4214)

# %%
features_test = features_tsfel(df_test, w_size=100, w_overlap=0, t_time=timedelta(microseconds=10000), n_jobs=6)
# Out:
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='6',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='7',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='79',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='24',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='24',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='45',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='36',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='51',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='9',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='39',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='6',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='6',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='25',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='12',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='34',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='15',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='31',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='54',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='20',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='8',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='2',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='1',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='13',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='8',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='69',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='12',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='6',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='4',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='40',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='49',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='41',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='4',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='8',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='33',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='2',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='8',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='2',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='6',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='1',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='7',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='23',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='8',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='15',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='6',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='2',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='6',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='30',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='14',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='2',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='2',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='7',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='11',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='6',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='4',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='15',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='2',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='73',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='1',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='49',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='21',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='4',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='24',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='7',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='8',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='15',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='83',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='31',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='51',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='47',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='2',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='39',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='50',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='17',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='9',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='21',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='7',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='38',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='6',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='12',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='11',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='2',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='6',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='4',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='27',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='2',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='31',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='80',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='11',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='45',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='20',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='117',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='38',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='36',
#                   style='width: 25%',
#               >
#                   0
#               </progress>

# %%
features_filt_50 = features_tsfel(df_filt, w_size=100, w_overlap=0.5, t_time=timedelta(microseconds=5000), n_jobs=6)
# Out:
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='73',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='11',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='273',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='61',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='17',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='69',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='75',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='85',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='35',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='13',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='57',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='23',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='7',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='11',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='7',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='29',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='35',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='15',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='11',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='21',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='81',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='51',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='165',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='93',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='69',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='85',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='17',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='1',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='25',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='7',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='55',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='57',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='31',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='139',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='51',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='19',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='19',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='45',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='9',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='15',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='17',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='35',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='117',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='123',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='79',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='13',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='41',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='43',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='31',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='113',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='81',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='11',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='27',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='67',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='9',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='15',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='73',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='19',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='147',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='65',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='87',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='101',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='41',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='59',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='119',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='133',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='195',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='163',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='9',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='11',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='11',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='13',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='15',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='7',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='1',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='19',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='1',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='81',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='11',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='19',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='33',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='13',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='77',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='39',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='29',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='9',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='45',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='47',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='9',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='9',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='1',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='7',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='35',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='47',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='41',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='23',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='13',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='39',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='43',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='21',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='17',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='19',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='15',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='45',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='99',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='7',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='99',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='55',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='15',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='63',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='13',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='15',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='77',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='44',
#                   style='width: 25%',
#               >
#                   0
#               </progress>

# %%
features_test_50 = features_tsfel(df_test, w_size=100, w_overlap=0.5, t_time=timedelta(microseconds=5000), n_jobs=6)
# Out:
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='11',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='13',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='157',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='47',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='47',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='9',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='89',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='71',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='101',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='17',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='77',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='11',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='11',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='49',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='23',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='67',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='9',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='9',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='29',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='61',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='107',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='39',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='15',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='9',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='1',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='25',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='15',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='137',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='23',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='11',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='7',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='79',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='97',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='81',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='7',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='15',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='65',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='15',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='11',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='1',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='13',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='45',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='9',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='15',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='29',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='11',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='11',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='59',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='27',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='13',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='21',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='11',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='9',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='7',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='29',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='145',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='1',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='9',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='97',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='41',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='7',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='47',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='13',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='15',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='29',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='165',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='61',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='101',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='93',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='77',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='99',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='33',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='17',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='41',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='13',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='75',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='11',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='23',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='5',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='21',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='9',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='11',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='9',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='7',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='53',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='3',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='61',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='159',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='21',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='89',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='39',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='233',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='75',
#                   style='width: 25%',
#               >
#                   0
#               </progress>
#               <p>
#                   Progress: 0% Complete
#               <p/>
#               <progress
#                   value='0'
#                   max='72',
#                   style='width: 25%',
#               >
#                   0
#               </progress>

# %%
lista_colunas = features_filt.columns.tolist()
print(lista_colunas)
# Out:
# ['Back.Acc.X_Absolute energy', 'Back.Acc.X_Area under the curve', 'Back.Acc.X_Autocorrelation', 'Back.Acc.X_Average power', 'Back.Acc.X_Centroid', 'Back.Acc.X_ECDF Percentile Count_0', 'Back.Acc.X_ECDF Percentile Count_1', 'Back.Acc.X_ECDF Percentile_0', 'Back.Acc.X_ECDF Percentile_1', 'Back.Acc.X_ECDF_0', 'Back.Acc.X_ECDF_1', 'Back.Acc.X_ECDF_2', 'Back.Acc.X_ECDF_3', 'Back.Acc.X_ECDF_4', 'Back.Acc.X_ECDF_5', 'Back.Acc.X_ECDF_6', 'Back.Acc.X_ECDF_7', 'Back.Acc.X_ECDF_8', 'Back.Acc.X_ECDF_9', 'Back.Acc.X_Entropy', 'Back.Acc.X_Fundamental frequency', 'Back.Acc.X_Histogram mode', 'Back.Acc.X_Human range energy', 'Back.Acc.X_Interquartile range', 'Back.Acc.X_Kurtosis', 'Back.Acc.X_LPCC_0', 'Back.Acc.X_LPCC_1', 'Back.Acc.X_LPCC_10', 'Back.Acc.X_LPCC_11', 'Back.Acc.X_LPCC_2', 'Back.Acc.X_LPCC_3', 'Back.Acc.X_LPCC_4', 'Back.Acc.X_LPCC_5', 'Back.Acc.X_LPCC_6', 'Back.Acc.X_LPCC_7', 'Back.Acc.X_LPCC_8', 'Back.Acc.X_LPCC_9', 'Back.Acc.X_MFCC_0', 'Back.Acc.X_MFCC_1', 'Back.Acc.X_MFCC_10', 'Back.Acc.X_MFCC_11', 'Back.Acc.X_MFCC_2', 'Back.Acc.X_MFCC_3', 'Back.Acc.X_MFCC_4', 'Back.Acc.X_MFCC_5', 'Back.Acc.X_MFCC_6', 'Back.Acc.X_MFCC_7', 'Back.Acc.X_MFCC_8', 'Back.Acc.X_MFCC_9', 'Back.Acc.X_Max', 'Back.Acc.X_Max power spectrum', 'Back.Acc.X_Maximum frequency', 'Back.Acc.X_Mean', 'Back.Acc.X_Mean absolute deviation', 'Back.Acc.X_Mean absolute diff', 'Back.Acc.X_Mean diff', 'Back.Acc.X_Median', 'Back.Acc.X_Median absolute deviation', 'Back.Acc.X_Median absolute diff', 'Back.Acc.X_Median diff', 'Back.Acc.X_Median frequency', 'Back.Acc.X_Min', 'Back.Acc.X_Negative turning points', 'Back.Acc.X_Neighbourhood peaks', 'Back.Acc.X_Peak to peak distance', 'Back.Acc.X_Positive turning points', 'Back.Acc.X_Power bandwidth', 'Back.Acc.X_Root mean square', 'Back.Acc.X_Signal distance', 'Back.Acc.X_Skewness', 'Back.Acc.X_Slope', 'Back.Acc.X_Spectral centroid', 'Back.Acc.X_Spectral decrease', 'Back.Acc.X_Spectral distance', 'Back.Acc.X_Spectral entropy', 'Back.Acc.X_Spectral kurtosis', 'Back.Acc.X_Spectral positive turning points', 'Back.Acc.X_Spectral roll-off', 'Back.Acc.X_Spectral roll-on', 'Back.Acc.X_Spectral skewness', 'Back.Acc.X_Spectral slope', 'Back.Acc.X_Spectral spread', 'Back.Acc.X_Spectral variation', 'Back.Acc.X_Spectrogram mean coefficient_0.0Hz', 'Back.Acc.X_Spectrogram mean coefficient_1.61Hz', 'Back.Acc.X_Spectrogram mean coefficient_11.29Hz', 'Back.Acc.X_Spectrogram mean coefficient_12.9Hz', 'Back.Acc.X_Spectrogram mean coefficient_14.52Hz', 'Back.Acc.X_Spectrogram mean coefficient_16.13Hz', 'Back.Acc.X_Spectrogram mean coefficient_17.74Hz', 'Back.Acc.X_Spectrogram mean coefficient_19.35Hz', 'Back.Acc.X_Spectrogram mean coefficient_20.97Hz', 'Back.Acc.X_Spectrogram mean coefficient_22.58Hz', 'Back.Acc.X_Spectrogram mean coefficient_24.19Hz', 'Back.Acc.X_Spectrogram mean coefficient_25.81Hz', 'Back.Acc.X_Spectrogram mean coefficient_27.42Hz', 'Back.Acc.X_Spectrogram mean coefficient_29.03Hz', 'Back.Acc.X_Spectrogram mean coefficient_3.23Hz', 'Back.Acc.X_Spectrogram mean coefficient_30.65Hz', 'Back.Acc.X_Spectrogram mean coefficient_32.26Hz', 'Back.Acc.X_Spectrogram mean coefficient_33.87Hz', 'Back.Acc.X_Spectrogram mean coefficient_35.48Hz', 'Back.Acc.X_Spectrogram mean coefficient_37.1Hz', 'Back.Acc.X_Spectrogram mean coefficient_38.71Hz', 'Back.Acc.X_Spectrogram mean coefficient_4.84Hz', 'Back.Acc.X_Spectrogram mean coefficient_40.32Hz', 'Back.Acc.X_Spectrogram mean coefficient_41.94Hz', 'Back.Acc.X_Spectrogram mean coefficient_43.55Hz', 'Back.Acc.X_Spectrogram mean coefficient_45.16Hz', 'Back.Acc.X_Spectrogram mean coefficient_46.77Hz', 'Back.Acc.X_Spectrogram mean coefficient_48.39Hz', 'Back.Acc.X_Spectrogram mean coefficient_50.0Hz', 'Back.Acc.X_Spectrogram mean coefficient_6.45Hz', 'Back.Acc.X_Spectrogram mean coefficient_8.06Hz', 'Back.Acc.X_Spectrogram mean coefficient_9.68Hz', 'Back.Acc.X_Standard deviation', 'Back.Acc.X_Sum absolute diff', 'Back.Acc.X_Variance', 'Back.Acc.X_Wavelet absolute mean_12.5Hz', 'Back.Acc.X_Wavelet absol ...

# %%
columns_mean_filt = df_filt.columns[df_filt.columns.str.contains(r'\.(X|Y|Z)_Mean$', regex=True)]
columns_mean_test = df_test.columns[df_test.columns.str.contains(r'\.(X|Y|Z)_Mean$', regex=True)]

dados_mean_filt = df_filt[columns_mean_filt]
dados_mean_test = df_test[columns_mean_test]

x_treino = dados_mean_filt
y_treino = df_filt["Position"]
x_teste = dados_mean_test
y_teste = df_test["Position"]

rf = RandomForestClassifier(
    n_estimators=300,        # número de árvores
    max_depth=12,          # deixe None inicialmente
    min_samples_split=2,
    min_samples_leaf=1,     # padrão bom para classificação
    bootstrap=True,
    n_jobs=6,
    random_state=42
)

rf.fit(x_treino, y_treino)
y_pred = rf.predict(x_teste)

acc = accuracy_score(y_teste, y_pred)
print(f"Acurácia: {acc:.4f}")

print(classification_report(y_teste, y_pred))

cm = confusion_matrix(y_teste, y_pred)
print(cm)
# Out:
# C:\Users\assis\AppData\Local\Temp\ipykernel_14876\1986011192.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   columns_mean_filt = df_filt.columns[df_filt.columns.str.contains(r'\.(X|Y|Z)_Mean$', regex=True)]
# C:\Users\assis\AppData\Local\Temp\ipykernel_14876\1986011192.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   columns_mean_test = df_test.columns[df_test.columns.str.contains(r'\.(X|Y|Z)_Mean$', regex=True)]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 22
#      10 y_teste = df_test["Position"]
#      12 rf = RandomForestClassifier(
#      13     n_estimators=300,        # número de árvores
#      14     max_depth=12,          # deixe None inicialmente
#    (...)     19     random_state=42
#      20 )
# ---> 22 rf.fit(x_treino, y_treino)
#      23 y_pred = rf.predict(x_teste)
#      25 acc = accuracy_score(y_teste, y_pred)
#
# File c:\Users\assis\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\assis\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\ensemble\_forest.py:359, in BaseForest.fit(self, X, y, sample_weight)
#     356 if issparse(y):
#     357     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 359 X, y = validate_data(
#     360     self,
#     361     X,
#     362     y,
#     363     multi_output=True,
#     364     accept_sparse="csc",
#     365     dtype=DTYPE,
#     366     ensure_all_finite=False,
#     367 )
#     368 # _compute_missing_values_in_feature_mask checks if X has missing values and
#     369 # will raise an error if the underlying tree base estimator can't handle missing
#     370 # values. Only the criterion is required to determine if the tree supports
#     371 # missing values.
#     372 estimator = type(self.estimator)(criterion=self.criterion)
#
# File c:\Users\assis\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2971, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2969         y = check_array(y, input_name="y", **check_y_params)
#    2970     else:
# -> 2971         X, y = check_X_y(X, y, **check_params)
#    2972     out = X, y
#    2974 if not no_val_X and check_params.get("ensure_2d", True):
#
# File c:\Users\assis\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:1368, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1362     raise ValueError(
#    1363         f"{estimator_name} requires y to be passed, but the target y is None"
#    1364     )
#    1366 ensure_all_finite = _deprecate_force_all_finite(force_all_finite, ensure_all_finite)
# -> 1368 X = check_array(
#    1369     X,
#    1370     accept_sparse=accept_sparse,
#    1371     accept_large_sparse=accept_large_sparse,
#    1372     dtype=dtype,
#    1373     order=order,
#    1374     copy=copy,
#    1375     force_writeable=force_writeable,
#    1376     ensure_all_finite=ensure_all_finite,
#    1377     ensure_2d=ensure_2d,
#    1378     allow_nd=allow_nd,
#    1379     ensure_min_samples=ensure_min_samples,
#    1380     ensure_min_features=ensure_min_features,
#    1381     estimator=estimator,
#    1382     input_name="X",
#    1383 )
#    1385 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1387 check_consistent_length(X, y)
#
# File c:\Users\assis\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:929, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     925 pandas_requires_conversion = any(
#     926     _pandas_dtype_needs_early_conversion(i) for i in dtypes_orig
#     927 )
#     928 if all(isinstance(dtype_iter, np.dtype) for dtype_iter in dtypes_orig):
# --> 929     dtype_orig = np.result_type(*dtypes_orig)
#     930 elif pandas_requires_conversion and any(d == object for d in dtypes_orig):
#     931     # Force object if any of the dtypes is an object
#     932     dtype_orig = object
#
# ValueError: at least one array or dtype is required

# %%
columns_std_filt = df_filt.columns[df_filt.columns.str.contains(r'\.(X|Y|Z)_Standard deviation$', regex=True)]
columns_std_test = df_test.columns[df_test.columns.str.contains(r'\.(X|Y|Z)_Standard deviation$', regex=True)]
dados_std_filt = df_filt[columns_std_filt]
dados_std_test = df_test[columns_std_test]
x_treino_std = dados_std_filt
x_teste_std = dados_std_test
y_treino_std = df_filt["Position"]
y_teste_std = df_test["Position"]

rf = RandomForestClassifier(
    n_estimators=300,        # número de árvores
    max_depth=12,          # deixe None inicialmente
    min_samples_split=2,
    min_samples_leaf=1,     # padrão bom para classificação
    bootstrap=True,
    n_jobs=6,
    random_state=42
)

rf.fit(x_treino_std, y_treino_std)
y_pred_std = rf.predict(x_teste_std)

acc_std = accuracy_score(y_teste_std, y_pred_std)
print(f"Acurácia (std): {acc_std:.4f}")

print(classification_report(y_teste_std, y_pred_std))
cm_std = confusion_matrix(y_teste_std, y_pred_std)
print(cm_std)
# Out:
# C:\Users\assis\AppData\Local\Temp\ipykernel_8376\4091284723.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   columns_std_filt = df_filt.columns[df_filt.columns.str.contains(r'\.(X|Y|Z)_Standard deviation$', regex=True)]
# C:\Users\assis\AppData\Local\Temp\ipykernel_8376\4091284723.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   columns_std_test = df_test.columns[df_test.columns.str.contains(r'\.(X|Y|Z)_Standard deviation$', regex=True)]
# Acurácia (std): 0.8578
#               precision    recall  f1-score   support
#
#   body shake       0.00      0.00      0.00         4
#   lying down       0.00      0.00      0.00         0
#      sitting       0.84      0.92      0.88       220
#     standing       0.82      0.70      0.75       127
#      walking       0.97      0.99      0.98        78
#
#     accuracy                           0.86       429
#    macro avg       0.53      0.52      0.52       429
# weighted avg       0.85      0.86      0.85       429
#
# [[  0   0   0   2   2]
#  [  0   0   0   0   0]
#  [  0   1 202  17   0]
#  [  0   0  38  89   0]
#  [  0   0   0   1  77]]
# c:\Users\assis\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\assis\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\assis\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\assis\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\assis\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\assis\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
# # Definindo os hiperparâmetros para Grid Search (3 valores para cada)
# param_grid = {
#     'n_estimators': [100, 200, 300],           # número de árvores
#     'max_depth': [10, 15, 20],                # profundidade máxima
#     'min_samples_leaf': [10, 20, 30]         # mínimo de amostras por folha
# }

# # Criando o modelo base
# rf_base = RandomForestClassifier(
#     n_estimators=300,        # número de árvores
#     max_depth=12,          # deixe None inicialmente
#     min_samples_split=2,
#     min_samples_leaf=1,     # padrão bom para classificação
#     bootstrap=True,
#     n_jobs=6,
#     random_state=42
# )

# # Grid Search com Cross-Validation de 5 folds
# # print("Iniciando Grid Search com 5-fold Cross-Validation...")
# # print(f"Total de combinações: {len(param_grid['n_estimators']) * len(param_grid['max_depth']) * len(param_grid['min_samples_leaf'])}")
# # print("="*60)

# # grid_search = GridSearchCV(
# #     estimator=rf_base,
# #     param_grid=param_grid,
# #     cv=5,                    # 5 folds
# #     scoring='accuracy',
# #     n_jobs=6,
# #     verbose=2,
# #     return_train_score=True
# # )
